# %%
import numpy as np
import pandas as pd

# %%
amazonsales = pd.read_csv('all_data.csv')

# %%
amazonsales.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
amazonsales.shape
# Out:
# (2802750, 6)

# %%
amazonsales.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count    2794575               2794575          2794575    2794575
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq        5325                328545          2528280     328545
#
#         Order Date  Purchase Address
# count      2794575           2794575
# unique      142396            140788
# top     Order Date  Purchase Address
# freq          5325              5325

# %%
amazonsales.isnull().sum()
# Out:
# Order ID            8175
# Product             8175
# Quantity Ordered    8175
# Price Each          8175
# Order Date          8175
# Purchase Address    8175
# dtype: int64

# %%
amazonsales = amazonsales.dropna(how='all')

# %%
amazonsales.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
amazonsales.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
amazonsales.dtypes
# Out:
# Order ID            object
# Product             object
# Quantity Ordered    object
# Price Each          object
# Order Date          object
# Purchase Address    object
# dtype: object

# %%
amazonsales = amazonsales.loc[(amazonsales['Order Date'].str[0:2] != 'Or')]

# %%
amazonsales.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 5  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %%
amazonsales['Order Date'] = pd.to_datetime(amazonsales['Order Date'])

# %%
amazonsales.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#            Order Date                      Purchase Address
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001

# %%
amazonsales['Year'] = amazonsales['Order Date'].dt.year

# %%
amazonsales['Month']  = amazonsales['Order Date'].dt.month

# %%
amazonsales['Hour'] = amazonsales['Order Date'].dt.hour

# %%
amazonsales.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#            Order Date                      Purchase Address  Year  Month  Hour
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001  2019      4     8
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215  2019      4    22
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  2019      4    14
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  2019      4    14
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001  2019      4     9

# %%
amazonsales['Price Each'] = pd.to_numeric(amazonsales['Price Each'])
amazonsales['Quantity Ordered'] = pd.to_numeric(amazonsales['Quantity Ordered'])

# %%
amazonsales.dtypes
# Out:
# Order ID                    object
# Product                     object
# Quantity Ordered             int64
# Price Each                 float64
# Order Date          datetime64[ns]
# Purchase Address            object
# Year                         int64
# Month                        int64
# Hour                         int64
# dtype: object

# %%
amazonsales['Sales'] = amazonsales['Price Each'] * amazonsales['Quantity Ordered']

# %%
amazonsales.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Year  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001  2019      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215  2019      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  2019      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  2019      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001  2019      4
#
#    Hour   Sales
# 0     8   23.90
# 2    22   99.99
# 3    14  600.00
# 4    14   11.99
# 5     9   11.99

# %% [markdown]
# # Since the DataFrame is cleaned we can now start analyzing the Data

# %% [markdown]
# ## Question 1: What was the best month for sales? How much was earned that month?

# %%
amazonsales.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Year  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001  2019      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215  2019      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  2019      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  2019      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001  2019      4
#
#    Hour   Sales
# 0     8   23.90
# 2    22   99.99
# 3    14  600.00
# 4    14   11.99
# 5     9   11.99

# %%
monthly_sales = amazonsales.groupby(['Month']).agg({'Sales': 'sum'})
monthly_sales.sort_values(by='Sales', ascending=False)

# The month with the highest sales is December, October and April
# Out:
#              Sales
# Month
# 12     69201650.10
# 10     56050903.20
# 4      50860053.60
# 11     47994048.00
# 5      47289101.25
# 3      42106505.70
# 7      39716636.40
# 6      38667033.90
# 8      33667018.20
# 2      33030336.30
# 9      31463401.95
# 1      27333850.95

# %% [markdown]
# ### Monthly Sales Graph

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\python310\lib\site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in c:\python310\lib\site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\python310\lib\site-packages (from seaborn) (3.5.2)
# Requirement already satisfied: numpy>=1.15 in c:\python310\lib\site-packages (from seaborn) (1.23.1)
# Requirement already satisfied: scipy>=1.0 in c:\python310\lib\site-packages (from seaborn) (1.9.0)
# Requirement already satisfied: cycler>=0.10 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\python310\lib\site-packages (from matplotlib>=2.2->seaborn) (9.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 22.2.1 is available.
# You should consider upgrading via the 'c:\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sns.set()
fig = plt.figure(figsize=(16,8))

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

ax = sns.barplot(x=monthly_sales.index, y=monthly_sales['Sales'], data=monthly_sales, palette='pastel')
ax.set_xticklabels(months)
plt.title("Amazon Monthly Sales")
plt.xlabel("Months")
plt.ylabel("Monthly Sales")




plt.show()

# %%
# pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %% [markdown]
# ## Question 2: What City had the highest number of sales?

# %%
amazonsales.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Year  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001  2019      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215  2019      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  2019      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  2019      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001  2019      4
#
#    Hour   Sales
# 0     8   23.90
# 2    22   99.99
# 3    14  600.00
# 4    14   11.99
# 5     9   11.99

# %%
def get_city(address):
    return address.split(',')[1]

def get_state(address):
    return address.split(',')[2].split(' ')[1]

# %%
amazonsales['Purchase Address'].apply(lambda x: get_city(x))
# Out:
# 0                  Dallas
# 2                  Boston
# 3             Los Angeles
# 4             Los Angeles
# 5             Los Angeles
#                 ...
# 2802745       Los Angeles
# 2802746     San Francisco
# 2802747     San Francisco
# 2802748     San Francisco
# 2802749     San Francisco
# Name: Purchase Address, Length: 2789250, dtype: object

# %%
amazonsales['Purchase Address'].apply(lambda x: get_state(x))
# Out:
# 0          TX
# 2          MA
# 3          CA
# 4          CA
# 5          CA
#            ..
# 2802745    CA
# 2802746    CA
# 2802747    CA
# 2802748    CA
# 2802749    CA
# Name: Purchase Address, Length: 2789250, dtype: object

# %%
amazonsales['City'] = amazonsales['Purchase Address'].apply(lambda x: get_city(x) + " " + get_state(x))

# %%
amazonsales.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Year  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001  2019      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215  2019      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  2019      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  2019      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001  2019      4
#
#    Hour   Sales             City
# 0     8   23.90        Dallas TX
# 2    22   99.99        Boston MA
# 3    14  600.00   Los Angeles CA
# 4    14   11.99   Los Angeles CA
# 5     9   11.99   Los Angeles CA

# %%
city_sales = amazonsales.groupby(['City']).agg({'Sales': 'sum'})
city_sales
# Out:
#                           Sales
# City
#  Atlanta GA        4.193248e+07
#  Austin TX         2.729373e+07
#  Boston MA         5.492463e+07
#  Dallas TX         4.151963e+07
#  Los Angeles CA    8.178856e+07
#  New York City NY  6.996476e+07
#  Portland ME       6.746374e+06
#  Portland OR       2.806099e+07
#  San Francisco CA  1.239331e+08
#  Seattle WA        4.121633e+07

# %%
city_sales['Sales'] = city_sales['Sales'].apply(lambda x: '%.5d' % x)

# %%
city_sales['Sales'] = city_sales['Sales'].astype('int64')

# %%
city_sales.sort_values(by='Sales', ascending=False)

# The City With the highest sales are San Francisco CA, Los Angeles CA, and New York City NY
# Out:
#                        Sales
# City
#  San Francisco CA  123933058
#  Los Angeles CA     81788562
#  New York City NY   69964761
#  Boston MA          54924630
#  Atlanta GA         41932478
#  Dallas TX          41519631
#  Seattle WA         41216332
#  Portland OR        28060985
#  Austin TX          27293726
#  Portland ME         6746374

# %%
fig = plt.figure(figsize=(16,8))

ax = sns.barplot(x=city_sales.index, y=city_sales['Sales'], data=city_sales)
ax.set_xticklabels(city_sales.index, rotation=30)

for i in range(len(city_sales.index)):
    plt.text(i, city_sales['Sales'][i], str(city_sales['Sales'][i]), ha='center', va='bottom')

plt.show()

# %% [markdown]
# ## Question 3: What time should we display advertisement to maximize likelihood of customer's buying product?

# %%
amazonsales.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Year  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001  2019      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215  2019      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  2019      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  2019      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001  2019      4
#
#    Hour   Sales             City
# 0     8   23.90        Dallas TX
# 2    22   99.99        Boston MA
# 3    14  600.00   Los Angeles CA
# 4    14   11.99   Los Angeles CA
# 5     9   11.99   Los Angeles CA

# %%
sns.set()

fig = plt.figure(figsize=(16,8))

hours = [hour for hour, dataframe in amazonsales.groupby('Hour')]

plt.plot(hours, amazonsales.groupby(['Hour']).count())
plt.xticks(hours)
plt.xlabel('Hours', size=12)
plt.ylabel('Number of Orders', size=12)

plt.show()

# The graph shows that the best time to advertise is around 11am and 7pm

# %% [markdown]
# ## Question 4: What products are most often sold together?

# %%
amazonsales.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 2   176559  Bose SoundSport Headphones                 1       99.99
# 3   176560                Google Phone                 1      600.00
# 4   176560            Wired Headphones                 1       11.99
# 5   176561            Wired Headphones                 1       11.99
#
#            Order Date                      Purchase Address  Year  Month  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001  2019      4
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215  2019      4
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  2019      4
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001  2019      4
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001  2019      4
#
#    Hour   Sales             City
# 0     8   23.90        Dallas TX
# 2    22   99.99        Boston MA
# 3    14  600.00   Los Angeles CA
# 4    14   11.99   Los Angeles CA
# 5     9   11.99   Los Angeles CA

# %%
amazonsales.reset_index(drop=True)
# Out:
#         Order ID                     Product  Quantity Ordered  Price Each  \
# 0         176558        USB-C Charging Cable                 2       11.95
# 1         176559  Bose SoundSport Headphones                 1       99.99
# 2         176560                Google Phone                 1      600.00
# 3         176560            Wired Headphones                 1       11.99
# 4         176561            Wired Headphones                 1       11.99
# ...          ...                         ...               ...         ...
# 2789245   259353      AAA Batteries (4-pack)                 3        2.99
# 2789246   259354                      iPhone                 1      700.00
# 2789247   259355                      iPhone                 1      700.00
# 2789248   259356      34in Ultrawide Monitor                 1      379.99
# 2789249   259357        USB-C Charging Cable                 1       11.95
#
#                  Order Date                         Purchase Address  Year  \
# 0       2019-04-19 08:46:00             917 1st St, Dallas, TX 75001  2019
# 1       2019-04-07 22:30:00        682 Chestnut St, Boston, MA 02215  2019
# 2       2019-04-12 14:38:00     669 Spruce St, Los Angeles, CA 90001  2019
# 3       2019-04-12 14:38:00     669 Spruce St, Los Angeles, CA 90001  2019
# 4       2019-04-30 09:27:00        333 8th St, Los Angeles, CA 90001  2019
# ...                     ...                                      ...   ...
# 2789245 2019-09-17 20:56:00   840 Highland St, Los Angeles, CA 90001  2019
# 2789246 2019-09-01 16:00:00  216 Dogwood St, San Francisco, CA 94016  2019
# 2789247 2019-09-23 07:39:00     220 12th St, San Francisco, CA 94016  2019
# 2789248 2019-09-19 17:30:00   511 Forest St, San Francisco, CA 94016  2019
# 2789249 2019-09-30 00:18:00   250 Meadow St, San Francisco, CA 94016  2019
#
#          Month  Hour   Sales               City
# 0            4     8   23.90          Dallas TX
# 1            4    22   99.99          Boston MA
# 2            4    14  600.00     Los Angeles CA
# 3            4    14   11.99     Los Angeles CA
# 4            4     9   11.99     Los Angeles CA
# ...        ...   ...     ...                ...
# 2789245      9    20    8.97     Los Angeles CA
# 2789246      9    16  700.00   San Francisco CA
# 2789247      9     7  700.00   San Francisco CA
# 2789248      9    17  379.99   San Francisco CA
# 2789249      9     0   11.95   San Francisco CA
#
# [2789250 rows x 11 columns]

# %%
sold_together = amazonsales[amazonsales.duplicated(subset='Order ID')]

sold_together['Grouped'] = sold_together.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
sold_together = sold_together[['Order ID', 'Grouped']].drop_duplicates()

sold_together.head()
# Out:
# C:\Users\pintu\AppData\Local\Temp\ipykernel_1268\229613758.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sold_together['Grouped'] = sold_together.groupby('Order ID')['Product'].transform(lambda x: ','.join(x))
#     Order ID                                            Grouped
# 4     176560  Wired Headphones,Google Phone,Wired Headphones...
# 19    176574  USB-C Charging Cable,Google Phone,USB-C Chargi...
# 31    176585  Bose SoundSport Headphones,Bose SoundSport Hea...
# 33    176586  Google Phone,AAA Batteries (4-pack),Google Pho...
# 120   176672  USB-C Charging Cable,Lightning Charging Cable,...
